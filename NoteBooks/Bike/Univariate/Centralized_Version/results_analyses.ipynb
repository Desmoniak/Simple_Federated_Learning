# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
X = list(range(6))
X_labels = ["(42, 70)", "(42,70,60)", "(42, 70, 60, 61)","(42, 70, 60, 61, 45)", "(42, 70, 60, 61, 45, 77)", "( 42, 70, 60, 61, 45, 77, 69)"]
Y1 = [0.6247, 0.6160, 0.6321, 0.5674, 0.5640, 0.6826]
Y2 = [0.1734, 0.1728, 0.1829, 0.1802, 0.1848, 0.1788]

# %%
plt.figure(figsize=(20, 10))
plt.plot(X, Y1, label="f(a(t), b(t), c(t)) => a(t+1), b(t+1), c(t+1)")
plt.plot(X, Y2, label="f(a(t), b(t), c(t)) => a(t+1)")
plt.xticks(X, X_labels)
plt.xticks(rotation=45, ha="right")
plt.xlabel("Stations")
plt.ylabel("loss")
plt.axhline(0.1716, color="red", label="LSTM")
plt.axhline(0.1722, color="black", label="GRU")
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
